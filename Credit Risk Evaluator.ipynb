# %% [markdown]
# ## Credit Risk Evaluator- Supervised Machine Learning

# %%
import numpy as np
import pandas as pd
from pathlib import Path
from sklearn.preprocessing import LabelEncoder

# %%
train_df = pd.read_csv(Path('Resources/2019loans.csv'))
test_df = pd.read_csv(Path('Resources/2020Q1loans.csv'))

# %%
train_df
# Out:
#        loan_amnt  int_rate  installment home_ownership  annual_inc  \
# 0         7000.0    0.1894       256.38       MORTGAGE     75000.0
# 1        40000.0    0.1614       975.71       MORTGAGE    102000.0
# 2        11000.0    0.2055       294.81           RENT     45000.0
# 3         4000.0    0.1612       140.87       MORTGAGE     38000.0
# 4        14000.0    0.1797       505.93       MORTGAGE     43000.0
# ...          ...       ...          ...            ...         ...
# 12175    19975.0    0.2565       801.09           RENT     28000.0
# 12176    15000.0    0.1774       540.34           RENT     50000.0
# 12177     3600.0    0.1862       131.28           RENT     60000.0
# 12178    15000.0    0.0881       475.68       MORTGAGE     62000.0
# 12179    15000.0    0.1774       540.34           RENT     54080.0
#
#       verification_status pymnt_plan    dti  delinq_2yrs  inq_last_6mths  ...  \
# 0            Not Verified          n  28.62          0.0             2.0  ...
# ...

# %%
test_df
# Out:
#       loan_amnt  int_rate  installment home_ownership  annual_inc  \
# 0       40000.0    0.1033       856.40           RENT    128700.0
# 1       24450.0    0.1430       572.72       MORTGAGE     44574.0
# 2       13500.0    0.1430       316.23            OWN     60000.0
# 3       10625.0    0.1774       268.31           RENT     60000.0
# 4        6375.0    0.1862       232.46           RENT     60000.0
# ...         ...       ...          ...            ...         ...
# 4697    30000.0    0.1240       673.42           RENT    140480.0
# 4698    24000.0    0.0756       747.22           RENT     50000.0
# 4699    10000.0    0.2305       387.36           RENT     33000.0
# 4700     8000.0    0.1862       205.86           RENT     38000.0
# 4701    30000.0    0.2055      1123.34           RENT    180000.0
#
#      verification_status pymnt_plan    dti  delinq_2yrs  inq_last_6mths  ...  \
# 0        Source Verified          n  12.47          0.0             1.0  ...
# ...

# %%
# Convert categorical data to numeric and separate target feature for training data
x_train = train_df.drop('target', axis=1)
y_train=train_df['target']

# %%
#Label Encoding
y_train = LabelEncoder().fit_transform(train_df['target'])
y_train
# Out:
# array([1, 1, 1, ..., 0, 0, 0])

# %%
# add missing dummy variables to testing set
#one-hot encoding
trn_features = pd.get_dummies(x_train)
print(trn_features.columns)
# Out:
# Index(['loan_amnt', 'int_rate', 'installment', 'annual_inc', 'dti',
#        'delinq_2yrs', 'inq_last_6mths', 'open_acc', 'pub_rec', 'revol_bal',
#        'total_acc', 'out_prncp', 'out_prncp_inv', 'total_pymnt',
#        'total_pymnt_inv', 'total_rec_prncp', 'total_rec_int',
#        'total_rec_late_fee', 'recoveries', 'collection_recovery_fee',
#        'last_pymnt_amnt', 'collections_12_mths_ex_med', 'policy_code',
#        'acc_now_delinq', 'tot_coll_amt', 'tot_cur_bal', 'open_acc_6m',
#        'open_act_il', 'open_il_12m', 'open_il_24m', 'mths_since_rcnt_il',
#        'total_bal_il', 'il_util', 'open_rv_12m', 'open_rv_24m', 'max_bal_bc',
#        'all_util', 'total_rev_hi_lim', 'inq_fi', 'total_cu_tl', 'inq_last_12m',
#        'acc_open_past_24mths', 'avg_cur_bal', 'bc_open_to_buy', 'bc_util',
#        'chargeoff_within_12_mths', 'delinq_amnt', 'mo_sin_old_il_acct',
#        'mo_sin_old_rev_tl_op', 'mo_sin_rcnt_rev_tl_op', 'mo_sin_rcnt_tl',
# ...

# %%
# Convert categorical data to numeric and separate target feature for testing data
x_test = test_df.drop('target', axis=1)
y_test=test_df['target']

# %%
# add missing dummy variables to testing set
#one-hot encoding
tst_features = pd.get_dummies(x_test)
print(tst_features.columns)
# Out:
# Index(['loan_amnt', 'int_rate', 'installment', 'annual_inc', 'dti',
#        'delinq_2yrs', 'inq_last_6mths', 'open_acc', 'pub_rec', 'revol_bal',
#        'total_acc', 'out_prncp', 'out_prncp_inv', 'total_pymnt',
#        'total_pymnt_inv', 'total_rec_prncp', 'total_rec_int',
#        'total_rec_late_fee', 'recoveries', 'collection_recovery_fee',
#        'last_pymnt_amnt', 'collections_12_mths_ex_med', 'policy_code',
#        'acc_now_delinq', 'tot_coll_amt', 'tot_cur_bal', 'open_acc_6m',
#        'open_act_il', 'open_il_12m', 'open_il_24m', 'mths_since_rcnt_il',
#        'total_bal_il', 'il_util', 'open_rv_12m', 'open_rv_24m', 'max_bal_bc',
#        'all_util', 'total_rev_hi_lim', 'inq_fi', 'total_cu_tl', 'inq_last_12m',
#        'acc_open_past_24mths', 'avg_cur_bal', 'bc_open_to_buy', 'bc_util',
#        'chargeoff_within_12_mths', 'delinq_amnt', 'mo_sin_old_il_acct',
#        'mo_sin_old_rev_tl_op', 'mo_sin_rcnt_rev_tl_op', 'mo_sin_rcnt_tl',
# ...

# %%
#Label Encoding
y_test = LabelEncoder().fit_transform(test_df['target'])
y_test
# Out:
# array([1, 1, 1, ..., 0, 0, 0])

# %%
x_train
# Out:
#        loan_amnt  int_rate  installment home_ownership  annual_inc  \
# 0         7000.0    0.1894       256.38       MORTGAGE     75000.0
# 1        40000.0    0.1614       975.71       MORTGAGE    102000.0
# 2        11000.0    0.2055       294.81           RENT     45000.0
# 3         4000.0    0.1612       140.87       MORTGAGE     38000.0
# 4        14000.0    0.1797       505.93       MORTGAGE     43000.0
# ...          ...       ...          ...            ...         ...
# 12175    19975.0    0.2565       801.09           RENT     28000.0
# 12176    15000.0    0.1774       540.34           RENT     50000.0
# 12177     3600.0    0.1862       131.28           RENT     60000.0
# 12178    15000.0    0.0881       475.68       MORTGAGE     62000.0
# 12179    15000.0    0.1774       540.34           RENT     54080.0
#
#       verification_status pymnt_plan    dti  delinq_2yrs  inq_last_6mths  ...  \
# 0            Not Verified          n  28.62          0.0             2.0  ...
# ...

# %%
for col in trn_features.columns:
    if col not in tst_features.columns:
        tst_features[col] = 0

# %% [markdown]
# # Models

# %%
# Train the Logistic Regression model on the unscaled data and print the model score
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(solver="lbfgs", max_iter=20000)
classifier.fit(trn_features, y_train)
# Out:
# LogisticRegression(max_iter=20000)

# %%
print(f"Training Data Score: {classifier.score(trn_features, y_train)}")
print(f"Testing Data Score: {classifier.score(tst_features, y_test)}")
# Out:
# Training Data Score: 0.7004926108374384
# Testing Data Score: 0.5655040408336878

# %%
# Train a Random Forest Classifier model and print the model score
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier(random_state=1, n_estimators=500).fit(trn_features, y_train)
print(f'Training Score: {clf.score(trn_features, y_train)}')
print(f'Testing Score: {clf.score(tst_features, y_test)}')
# Out:
# Training Score: 1.0
# Testing Score: 0.646958740961293

# %%
# Scale the data
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler().fit(trn_features)
trn_features_scaled = scaler.transform(trn_features)
tst_features_scaled = scaler.transform(tst_features)

# %%
# Train the Logistic Regression model on the scaled data and print the model score
classifier.fit(trn_features_scaled, y_train)
print(f"Training Data Score: {classifier.score(trn_features_scaled, y_train)}")
print(f"Testing Data Score: {classifier.score(tst_features_scaled, y_test)}")
# Out:
# Training Data Score: 0.710919540229885
# Testing Data Score: 0.7598894087622289

# %%
# Train a Random Forest Classifier model on the scaled data and print the model score
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier(random_state=1, n_estimators=500).fit(trn_features, y_train)
print(f'Training Score: {clf.score(trn_features, y_train)}')
print(f'Testing Score: {clf.score(tst_features, y_test)}')
# Out:
# Training Score: 1.0
# Testing Score: 0.646958740961293

# %% [markdown]
# ## Initial Thoughts:
#
# ### I believed that the random forest classifer would perform better. From reading it seemed that Random forest would be better at dealing with categorical data.
#
# ##  Conclusions:
#
# ### The random forest model performed better before scaling, but once scaled the logistic regression model was the better fit.
